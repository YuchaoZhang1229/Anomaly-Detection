# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import Input, Dense, LSTM, RepeatVector, TimeDistributed, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers
import tensorflow as tf

# %%
def del_no_pump_index(df):
    """
    Deletes the rows where the pump is not running
    """
    orginal = df.shape[0]

    # 找出没有被pump的pump_index
    pump_index = df['pump_index'].unique()
    nopump_index = []
    nopump_symbol = []
    for i in pump_index:
        df_pump = df[df['pump_index'] == i]
        # 如果df_pump的列gt不存在等于1, 打印i
        if 1 not in df_pump['gt'].values:
            nopump_symbol.append(df_pump['symbol'].unique().tolist()[0])
            nopump_index.append(i)
    print('nopump_index: ', nopump_index)
    print('nopump_symbol: ', nopump_symbol)

    print('df.shape: ', df.shape)
    print(df['pump_index'].unique().shape)

    # 删除pump_index的值等于48的行
    for i in nopump_index:
        df = df.drop(df[df['pump_index'] == i].index)

    print('df_cleaned.shape: ', df.shape)
    print(df['pump_index'].unique().shape)
    now = df.shape[0]
    print('deleted: ', orginal - now)
    return df

# %%
# --------------------------------------------------------------------------------------------------
def lstm_autoencoder(time_freq):
    df = pd.read_csv('before_pump/before_pump_3D_' + time_freq + '.csv', parse_dates=['date'])

    features = ['std_rush_order',
                'avg_rush_order',
                'std_trades',
                'std_volume',
                'avg_volume',
                'std_price',
                'avg_price',
                'avg_price_max',
                'hour_sin',
                'hour_cos',
                'minute_sin',
                'minute_cos']

    df = del_no_pump_index(df)

    X = df[features]
    Y = df['gt'].astype(int).values.ravel()

    # normalize
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    # normal data
    X_normal = X[Y == 0]
    Y_normal = Y[Y == 0]

    # abnormal data
    X_abnormal = X[Y == 1]
    Y_abnormal = Y[Y == 1]

    # train test split
    X_train, X_test, y_train, y_test = train_test_split(X_normal, Y_normal, test_size=0.2, random_state=2023)
    
    # 拼接X_test和X_abnormal
    X_test = np.concatenate((X_test, X_abnormal), axis=0)
    y_test = np.concatenate((y_test, Y_abnormal), axis=0)

    # 将时间序列数据转换为适用于LSTM自编码器的输入格式
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    # 构建LSTM自编码器模型
    reg = 0.0001
    inputs = Input(shape=(X_train.shape[1],X_train.shape[2]))
    encoded = LSTM(32, activation='relu', return_sequences=True, kernel_regularizer=regularizers.l2(reg))(inputs)
    encoded = LSTM(16, activation='relu', return_sequences=False)(encoded)
    decoded = RepeatVector(X_train.shape[1])(encoded)
    decoded = LSTM(16, activation='relu', return_sequences=True,)(decoded)
    decoded = LSTM(32, activation='relu', return_sequences=True)(decoded)
    outputs = TimeDistributed(Dense(X_train.shape[2]))(decoded)
    autoencoder = Model(inputs, outputs)
    autoencoder.compile(optimizer='adam', loss='mae')
    # adam = optimizers.Adam(learning_rate=0.0001)
    # autoencoder.compile(optimizer=adam, loss='mae')
    # autoencoder.summary()
    
    # 使用训练数据训练LSTM自编码器模型
    early_stopping = EarlyStopping(monitor='val_loss'
                                # , min_delta=0.0001
                                , patience=12
                                , verbose=1
                                # , mode='min'
                                , restore_best_weights=True)
    history= autoencoder.fit(X_train, X_train
                            , epochs=150
                            , batch_size=32
                            , validation_split=0.1
                            , callbacks=[early_stopping]
                            )

    # plot loss curve
    fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
    ax.plot(history.history['loss'], 'b', label='Train', linewidth=2)
    ax.plot(history.history['val_loss'], 'r', label='Validation', linewidth=2)
    ax.set_title('LSTM-AutoEncoder Model loss', fontsize=16)
    ax.set_ylabel('Loss (mae)')
    ax.set_xlabel('Epoch')
    ax.legend(loc='upper right')
    plt.show()

    # 使用训练好的LSTM自编码器重构测试数据
    X_test_pred = autoencoder.predict(X_test)
    X_test_pred = X_test_pred.reshape(X_test_pred.shape[0], X_test_pred.shape[2])
    testX = X_test.reshape(X_test.shape[0], X_test.shape[2])

    # 计算还原误差MAE
    test_mae = np.mean(np.abs(testX - X_test_pred), axis=1)

    return autoencoder, test_mae, y_test



# --------------------------------------------------------------------------------------------------
def pick_threshold(y, preds):
    thresholds = np.linspace(0, 1, 1000)
    f1_scores = [f1_score(y, preds > t) for t in thresholds]
    precision_scores = [precision_score(y, preds > t) for t in thresholds]
    recall_scores = [recall_score(y, preds > t) for t in thresholds]
    plt.figure(figsize=(12, 6))
    plt.plot(thresholds, f1_scores, label='F1 Score')
    plt.plot(thresholds, precision_scores, label='Precision')
    plt.plot(thresholds, recall_scores, label='Recall')
    plt.axvline(x=thresholds[np.argmax(f1_scores)], color='r', linestyle='--', label='Max F1 Score')
    plt.title('F1 Score w.r.t varying threshold')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.show()
    best_threshold = thresholds[np.argmax(f1_scores)]
    print('Best threshold: ', best_threshold)
    print('Best F1 Score: ', np.max(f1_scores))
    print('Recall: ', recall_score(y, preds > best_threshold))
    print('Precision: ', precision_score(y, preds > best_threshold))
    

    cm = confusion_matrix(y, preds > best_threshold)
    plt.figure(figsize=(10, 6))
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title('LSTM-AutoEncoder - Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
    return best_threshold
# ------------------------------set threshold--------------------------------------------------------
def set_threshold(y_test, test_mae, threshold):
    # 设置阈值
    threshold = threshold
    print("Reconstruction error threshold: ", threshold)
    y_test_pred = np.where(test_mae >= threshold , 1, 0)

    # precision, recall, f1-score
    print('F1 score: {}'.format(f1_score(y_test, y_test_pred)))
    print('Recall: {}'.format(recall_score(y_test, y_test_pred)))
    print('Precision: {}'.format(precision_score(y_test, y_test_pred)))
    

    # plot confusion matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_test_pred)
    plt.figure(figsize=(10, 6))
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title('LSTM-AutoEncoder - Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %% [markdown]
# # LSTM AutoEncoder

# %% [markdown]
# - 25S

# %%
autoencoder_25S, test_mae_25S, y_test_25S = lstm_autoencoder(time_freq='25S') # 6m 51s
# Out:
# nopump_index:  []
# nopump_symbol:  []
# df.shape:  (86725, 16)
# (317,)
# df_cleaned.shape:  (86725, 16)
# (317,)
# deleted:  0
# Epoch 1/150
# 1945/1945 [==============================] - 8s 2ms/step - loss: 0.1924 - val_loss: 0.0870
# Epoch 2/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0801 - val_loss: 0.0520
# Epoch 3/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0413 - val_loss: 0.0379
# Epoch 4/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0376 - val_loss: 0.0408
# Epoch 5/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0370 - val_loss: 0.0380
# Epoch 6/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0366 - val_loss: 0.0368
# Epoch 7/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0365 - val_loss: 0.0378
# Epoch 8/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0361 - val_loss: 0.0367
# Epoch 9/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0354 - val_loss: 0.0361
# Epoch 10/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0309 - val_loss: 0.0273
# Epoch 11/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0264 - val_loss: 0.0275
# Epoch 12/150
# 1945/1945 [==============================] - 5s 2ms/step - loss: 0.0255 - val_loss: 0.0268
# Epoch 13/150
# 1945/1945 [==============================] - 5s 3ms/step - loss: 0.0251 - val_loss: 0.0267
# Epoch 14/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0248 - val_loss: 0.0248
# Epoch 15/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0246 - val_loss: 0.0253
# Epoch 16/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0245 - val_loss: 0.0245
# Epoch 17/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0243 - val_loss: 0.0261
# Epoch 18/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0242 - val_loss: 0.0240
# Epoch 19/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0241 - val_loss: 0.0263
# Epoch 20/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0241 - val_loss: 0.0244
# Epoch 21/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0240 - val_loss: 0.0245
# Epoch 22/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0240 - val_loss: 0.0270
# Epoch 23/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0239 - val_loss: 0.0257
# Epoch 24/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0237 - val_loss: 0.0241
# Epoch 25/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0237 - val_loss: 0.0253
# Epoch 26/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0237 - val_loss: 0.0243
# Epoch 27/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0236 - val_loss: 0.0244
# Epoch 28/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0236 - val_loss: 0.0237
# Epoch 29/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0236 - val_loss: 0.0235
# Epoch 30/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0235 - val_loss: 0.0238
# Epoch 31/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0235 - val_loss: 0.0237
# Epoch 32/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0234 - val_loss: 0.0246
# Epoch 33/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0233 - val_loss: 0.0232
# Epoch 34/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0232 - val_loss: 0.0245
# Epoch 35/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0230 - val_loss: 0.0245
# Epoch 36/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0224 - val_loss: 0.0232
# Epoch 37/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0195 - val_loss: 0.0171
# Epoch 38/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0149 - val_loss: 0.0138
# Epoch 39/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0138 - val_loss: 0.0142
# Epoch 40/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0135 - val_loss: 0.0141
# Epoch 41/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0131 - val_loss: 0.0138
# Epoch 42/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0130 - val_loss: 0.0137
# Epoch 43/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0127 - val_loss: 0.0155
# Epoch 44/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 45/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0128 - val_loss: 0.0128
# Epoch 46/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 47/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 48/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0124 - val_loss: 0.0129
# Epoch 49/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0125 - val_loss: 0.0125
# Epoch 50/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0123 - val_loss: 0.0129
# Epoch 51/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0123 - val_loss: 0.0126
# Epoch 52/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0124 - val_loss: 0.0125
# Epoch 53/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0122 - val_loss: 0.0124
# Epoch 54/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0122 - val_loss: 0.0142
# Epoch 55/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0123 - val_loss: 0.0125
# Epoch 56/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 57/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0122 - val_loss: 0.0123
# Epoch 58/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0121 - val_loss: 0.0127
# Epoch 59/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0120 - val_loss: 0.0123
# Epoch 60/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0122 - val_loss: 0.0144
# Epoch 61/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 62/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 63/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0120 - val_loss: 0.0124
# Epoch 64/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0120 - val_loss: 0.0139
# Epoch 65/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0120 - val_loss: 0.0133
# Epoch 66/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0120 - val_loss: 0.0131
# Epoch 67/150
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0119 - val_loss: 0.0149
# Epoch 68/150
# 1919/1945 [============================>.] - ETA: 0s - loss: 0.0119Restoring model weights from the end of the best epoch: 56.
# 1945/1945 [==============================] - 4s 2ms/step - loss: 0.0119 - val_loss: 0.0130
# Epoch 68: early stopping
# 550/550 [==============================] - 1s 882us/step

# %%
threshold_25S = pick_threshold(y_test_25S, test_mae_25S)



# Before 1 Days
# Best threshold:  0.26626626626626626
# Best F1 Score:  0.9540412044374009
# Recall:  0.9495268138801262
# Precision:  0.9585987261146497

# Before 3 Days
# Best threshold:  0.26926926926926925
# Best F1 Score:  0.9198717948717948
# Recall:  0.9053627760252366
# Precision:  0.9348534201954397

# Before 7 Days
# Best threshold:  0.38038038038038036
# Best F1 Score:  0.8928571428571429
# Recall:  0.8675078864353313
# Precision:  0.919732441471572
# Out:
# Best threshold:  0.26926926926926925
# Best F1 Score:  0.9198717948717948
# Recall:  0.9053627760252366
# Precision:  0.9348534201954397

# %% [markdown]
# - 15S

# %%
autoencoder_15S, test_mae_15S, y_test_15S = lstm_autoencoder(time_freq='15S') # 4m 32s
# Out:
# nopump_index:  []
# nopump_symbol:  []
# df.shape:  (103566, 16)
# (317,)
# df_cleaned.shape:  (103566, 16)
# (317,)
# deleted:  0
# Epoch 1/150
# 2324/2324 [==============================] - 9s 2ms/step - loss: 0.2038 - val_loss: 0.1230
# Epoch 2/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.1198 - val_loss: 0.1192
# Epoch 3/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.1098 - val_loss: 0.0638
# Epoch 4/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0564 - val_loss: 0.0554
# Epoch 5/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0540 - val_loss: 0.0547
# Epoch 6/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0503 - val_loss: 0.0417
# Epoch 7/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0361 - val_loss: 0.0358
# Epoch 8/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0342 - val_loss: 0.0335
# Epoch 9/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0334 - val_loss: 0.0343
# Epoch 10/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0330 - val_loss: 0.0325
# Epoch 11/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0316 - val_loss: 0.0317
# Epoch 12/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0255 - val_loss: 0.0218
# Epoch 13/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0217 - val_loss: 0.0238
# Epoch 14/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0205 - val_loss: 0.0208
# Epoch 15/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0194 - val_loss: 0.0199
# Epoch 16/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0191 - val_loss: 0.0221
# Epoch 17/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0185 - val_loss: 0.0187
# Epoch 18/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0182 - val_loss: 0.0195
# Epoch 19/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0181 - val_loss: 0.0178
# Epoch 20/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0179 - val_loss: 0.0188
# Epoch 21/150
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.0177 - val_loss: 0.0200
# Epoch 22/150
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.0175 - val_loss: 0.0190
# Epoch 23/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0174 - val_loss: 0.0181
# Epoch 24/150
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.0174 - val_loss: 0.0201
# Epoch 25/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0172 - val_loss: 0.0184
# Epoch 26/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0171 - val_loss: 0.0164
# Epoch 27/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 28/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0169 - val_loss: 0.0183
# Epoch 29/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0169 - val_loss: 0.0188
# Epoch 30/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0168 - val_loss: 0.0215
# Epoch 31/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0167 - val_loss: 0.0168
# Epoch 32/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0167 - val_loss: 0.0184
# Epoch 33/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0166 - val_loss: 0.0186
# Epoch 34/150
# 2324/2324 [==============================] - 5s 2ms/step - loss: 0.0165 - val_loss: 0.0176
# Epoch 35/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0164 - val_loss: 0.0175
# Epoch 36/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0162 - val_loss: 0.0186
# Epoch 37/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0163 - val_loss: 0.0151
# Epoch 38/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 39/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0159 - val_loss: 0.0160
# Epoch 40/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0156 - val_loss: 0.0176
# Epoch 41/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0150 - val_loss: 0.0139
# Epoch 42/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0141 - val_loss: 0.0170
# Epoch 43/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 44/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0135 - val_loss: 0.0142
# Epoch 45/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0132 - val_loss: 0.0153
# Epoch 46/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0131 - val_loss: 0.0137
# Epoch 47/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0130 - val_loss: 0.0132
# Epoch 48/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0131 - val_loss: 0.0111
# Epoch 49/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0129 - val_loss: 0.0124
# Epoch 50/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0129 - val_loss: 0.0141
# Epoch 51/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0130 - val_loss: 0.0134
# Epoch 52/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0129 - val_loss: 0.0151
# Epoch 53/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0129 - val_loss: 0.0133
# Epoch 54/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0128 - val_loss: 0.0150
# Epoch 55/150
# 2324/2324 [==============================] - 6s 2ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 56/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0128 - val_loss: 0.0130
# Epoch 57/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0127 - val_loss: 0.0149
# Epoch 58/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0127 - val_loss: 0.0134
# Epoch 59/150
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0127 - val_loss: 0.0132
# Epoch 60/150
# 2323/2324 [============================>.] - ETA: 0s - loss: 0.0126Restoring model weights from the end of the best epoch: 48.
# 2324/2324 [==============================] - 6s 3ms/step - loss: 0.0126 - val_loss: 0.0132
# Epoch 60: early stopping
# 656/656 [==============================] - 1s 1ms/step

# %%
threshold_15S = pick_threshold(y_test_15S, test_mae_15S)



# Before 1 Days
# Best threshold:  0.1871871871871872
# Best F1 Score:  0.9170579029733958
# Recall:  0.9242902208201893
# Precision:  0.9099378881987578

# Before 3 Days
# Best threshold:  0.21021021021021022
# Best F1 Score:  0.8744186046511628
# Recall:  0.889589905362776
# Precision:  0.8597560975609756

# Before 7 Days
# Best threshold:  0.47047047047047047
# Best F1 Score:  0.8607198748043818
# Recall:  0.8675078864353313
# Precision:  0.8540372670807453
# Out:
# Best threshold:  0.21021021021021022
# Best F1 Score:  0.8744186046511628
# Recall:  0.889589905362776
# Precision:  0.8597560975609756

# %% [markdown]
# - 5S

# %%
autoencoder_5S, test_mae_5S, y_test_5S = lstm_autoencoder(time_freq='5S')
# Out:
# nopump_index:  []
# nopump_symbol:  []
# df.shape:  (144252, 16)
# (317,)
# df_cleaned.shape:  (144252, 16)
# (317,)
# deleted:  0
# Epoch 1/150
# 3239/3239 [==============================] - 12s 3ms/step - loss: 0.1956 - val_loss: 0.0775
# Epoch 2/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0726 - val_loss: 0.0707
# Epoch 3/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0622 - val_loss: 0.0437
# Epoch 4/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0432 - val_loss: 0.0413
# Epoch 5/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0369 - val_loss: 0.0302
# Epoch 6/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0273 - val_loss: 0.0253
# Epoch 7/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0251 - val_loss: 0.0225
# Epoch 8/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0242 - val_loss: 0.0243
# Epoch 9/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0236 - val_loss: 0.0228
# Epoch 10/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0231 - val_loss: 0.0245
# Epoch 11/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0227 - val_loss: 0.0220
# Epoch 12/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0224 - val_loss: 0.0230
# Epoch 13/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0222 - val_loss: 0.0241
# Epoch 14/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0222 - val_loss: 0.0239
# Epoch 15/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0219 - val_loss: 0.0223
# Epoch 16/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0216 - val_loss: 0.0217
# Epoch 17/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0215 - val_loss: 0.0230
# Epoch 18/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 19/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0212 - val_loss: 0.0218
# Epoch 20/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0211 - val_loss: 0.0236
# Epoch 21/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0210 - val_loss: 0.0219
# Epoch 22/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0209 - val_loss: 0.0213
# Epoch 23/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0208 - val_loss: 0.0208
# Epoch 24/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0207 - val_loss: 0.0209
# Epoch 25/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0206 - val_loss: 0.0214
# Epoch 26/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0206 - val_loss: 0.0206
# Epoch 27/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0205 - val_loss: 0.0204
# Epoch 28/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0204 - val_loss: 0.0227
# Epoch 29/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0203 - val_loss: 0.0230
# Epoch 30/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0204 - val_loss: 0.0204
# Epoch 31/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0202 - val_loss: 0.0202
# Epoch 32/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0202 - val_loss: 0.0205
# Epoch 33/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0201 - val_loss: 0.0233
# Epoch 34/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0201 - val_loss: 0.0224
# Epoch 35/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0200 - val_loss: 0.0217
# Epoch 36/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0200 - val_loss: 0.0207
# Epoch 37/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0199 - val_loss: 0.0220
# Epoch 38/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0199 - val_loss: 0.0201
# Epoch 39/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0200 - val_loss: 0.0203
# Epoch 40/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0199 - val_loss: 0.0199
# Epoch 41/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0198 - val_loss: 0.0206
# Epoch 42/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0198 - val_loss: 0.0202
# Epoch 43/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0197 - val_loss: 0.0209
# Epoch 44/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0198 - val_loss: 0.0214
# Epoch 45/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0196 - val_loss: 0.0198
# Epoch 46/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0197 - val_loss: 0.0203
# Epoch 47/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0196 - val_loss: 0.0206
# Epoch 48/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0197 - val_loss: 0.0213
# Epoch 49/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0195 - val_loss: 0.0203
# Epoch 50/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0195 - val_loss: 0.0208
# Epoch 51/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0194 - val_loss: 0.0200
# Epoch 52/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0194 - val_loss: 0.0204
# Epoch 53/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0193 - val_loss: 0.0204
# Epoch 54/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0192 - val_loss: 0.0214
# Epoch 55/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0193 - val_loss: 0.0186
# Epoch 56/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0193 - val_loss: 0.0211
# Epoch 57/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0192 - val_loss: 0.0197
# Epoch 58/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0191 - val_loss: 0.0199
# Epoch 59/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0192 - val_loss: 0.0217
# Epoch 60/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0192 - val_loss: 0.0211
# Epoch 61/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0191 - val_loss: 0.0209
# Epoch 62/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0191 - val_loss: 0.0201
# Epoch 63/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0190 - val_loss: 0.0199
# Epoch 64/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0190 - val_loss: 0.0189
# Epoch 65/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0189 - val_loss: 0.0186
# Epoch 66/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0190 - val_loss: 0.0201
# Epoch 67/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0190 - val_loss: 0.0191
# Epoch 68/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0189 - val_loss: 0.0196
# Epoch 69/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0189 - val_loss: 0.0189
# Epoch 70/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0188 - val_loss: 0.0204
# Epoch 71/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0186 - val_loss: 0.0188
# Epoch 72/150
# 3239/3239 [==============================] - 6s 2ms/step - loss: 0.0183 - val_loss: 0.0169
# Epoch 73/150
# 3239/3239 [==============================] - 6s 2ms/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 74/150
# 3239/3239 [==============================] - 6s 2ms/step - loss: 0.0144 - val_loss: 0.0142
# Epoch 75/150
# 3239/3239 [==============================] - 6s 2ms/step - loss: 0.0141 - val_loss: 0.0153
# Epoch 76/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0138 - val_loss: 0.0139
# Epoch 77/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0137 - val_loss: 0.0134
# Epoch 78/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0136 - val_loss: 0.0134
# Epoch 79/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0136 - val_loss: 0.0143
# Epoch 80/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0135 - val_loss: 0.0130
# Epoch 81/150
# 3239/3239 [==============================] - 7s 2ms/step - loss: 0.0134 - val_loss: 0.0140
# Epoch 82/150
# 3239/3239 [==============================] - 8s 2ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 83/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0134 - val_loss: 0.0138
# Epoch 84/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 85/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 86/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0133 - val_loss: 0.0124
# Epoch 87/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0133 - val_loss: 0.0140
# Epoch 88/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 89/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0132 - val_loss: 0.0129
# Epoch 90/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0132 - val_loss: 0.0130
# Epoch 91/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0132 - val_loss: 0.0130
# Epoch 92/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0132 - val_loss: 0.0130
# Epoch 93/150
# 3239/3239 [==============================] - 8s 3ms/step - loss: 0.0132 - val_loss: 0.0134
# Epoch 94/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0131 - val_loss: 0.0128
# Epoch 95/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0131 - val_loss: 0.0130
# Epoch 96/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 97/150
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0131 - val_loss: 0.0129
# Epoch 98/150
# 3235/3239 [============================>.] - ETA: 0s - loss: 0.0131Restoring model weights from the end of the best epoch: 86.
# 3239/3239 [==============================] - 9s 3ms/step - loss: 0.0131 - val_loss: 0.0131
# Epoch 98: early stopping
# 910/910 [==============================] - 1s 1ms/step

# %%
threshold_5S = pick_threshold(y_test_5S, test_mae_5S)



# Before 1 Day
# Best threshold:  0.2132132132132132
# Best F1 Score:  0.8722466960352423
# Recall:  0.9369085173501577
# Precision:  0.8159340659340659

# Before 3 Day
# Best threshold:  0.32932932932932935
# Best F1 Score:  0.8652931854199684
# Recall:  0.861198738170347
# Precision:  0.8694267515923567


# Before 7 Day
# Best threshold:  0.4044044044044044
# Best F1 Score:  0.8310502283105022
# Recall:  0.861198738170347
# Precision:  0.8029411764705883
# Out:
# Best threshold:  0.32932932932932935
# Best F1 Score:  0.8652931854199684
# Recall:  0.861198738170347
# Precision:  0.8694267515923567

# %%
# 设置阈值
print("Reconstruction error threshold_5S: ", threshold_5S)
print("Reconstruction error threshold_15S: ", threshold_15S)
print("Reconstruction error threshold_25S: ", threshold_25S)

# Sigmoid 函数
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


y_test_pred_5S = np.where(test_mae_5S >= threshold_5S , 1, 0)
y_test_pred_15S = np.where(test_mae_15S >= threshold_15S , 1, 0)
y_test_pred_25S = np.where(test_mae_25S >= threshold_25S , 1, 0)

y_test_prod_5S = sigmoid(y_test_pred_5S)
y_test_prod_15S = sigmoid(y_test_pred_15S)
y_test_prod_25S = sigmoid(y_test_pred_25S)

# precision, recall, f1-score
from sklearn.metrics import f1_score, recall_score, precision_score
F1_score_5S = f1_score(y_test_5S, y_test_pred_5S)
Recall_5S = recall_score(y_test_5S, y_test_pred_5S)
Precision_5S = precision_score(y_test_5S, y_test_pred_5S)

F1_score_15S = f1_score(y_test_15S, y_test_pred_15S)
Recall_15S = recall_score(y_test_15S, y_test_pred_15S)
Precision_15S = precision_score(y_test_15S, y_test_pred_15S)

F1_score_25S = f1_score(y_test_25S, y_test_pred_25S)
Recall_25S = recall_score(y_test_25S, y_test_pred_25S)
Precision_25S = precision_score(y_test_25S, y_test_pred_25S)

print('5S: F1 Score: {}, Recall: {}, Precision: {}'.format(F1_score_5S, Recall_5S, Precision_5S))
print('15S: F1 Score: {}, Recall: {}, Precision: {}'.format(F1_score_15S, Recall_15S, Precision_15S))
print('25S: F1 Score: {}, Recall: {}, Precision: {}'.format(F1_score_25S, Recall_25S, Precision_25S))

# plot confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix_5S = confusion_matrix(y_test_5S, y_test_pred_5S)
confusion_matrix_15S = confusion_matrix(y_test_15S, y_test_pred_15S)
confusion_matrix_25S = confusion_matrix(y_test_25S, y_test_pred_25S)

plt.figure(figsize=(40,10))
plt.subplot(1,3,1)
plt.title('5S')
sns.heatmap(confusion_matrix_5S, annot=True, fmt="d", cmap=plt.cm.Blues, xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted label')
plt.ylabel('True label')

plt.subplot(1,3,2)
plt.title('15S')
sns.heatmap(confusion_matrix_15S, annot=True, fmt="d", cmap=plt.cm.Blues, xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted label')
plt.ylabel('True label')

plt.subplot(1,3,3)
plt.title('25S')
sns.heatmap(confusion_matrix_25S, annot=True, fmt="d", cmap=plt.cm.Blues, xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted label')
plt.ylabel('True label')


# plot ROC curve
from sklearn.metrics import roc_curve, auc
# fpr_5S, tpr_5S, thresholds_5S = roc_curve(y_test_5S, y_test_pred_5S)
fpr_5S, tpr_5S, thresholds_5S = roc_curve(y_test_5S, y_test_prod_5S)

roc_auc_5S = auc(fpr_5S, tpr_5S)

# fpr_15S, tpr_15S, thresholds_15S = roc_curve(y_test_15S, y_test_pred_15S)
fpr_15S, tpr_15S, thresholds_15S = roc_curve(y_test_15S, y_test_prod_15S)
roc_auc_15S = auc(fpr_15S, tpr_15S)

# fpr_25S, tpr_25S, thresholds_25S = roc_curve(y_test_25S, y_test_pred_25S)
fpr_25S, tpr_25S, thresholds_25S = roc_curve(y_test_25S, y_test_prod_25S)
roc_auc_25S = auc(fpr_25S, tpr_25S)

plt.figure(figsize=(10,10))
plt.plot(fpr_5S, tpr_5S, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc_5S) # lw: line width
plt.plot(fpr_15S, tpr_15S, color='green', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc_15S) # lw: line width
plt.plot(fpr_25S, tpr_25S, color='red', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc_25S) # lw: line width
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--') # 画对角线
# plt.xlim([0.0, 1.0]) # x轴范围
plt.ylim([0.0, 1.05]) # y轴范围
plt.xlabel('False Positive Rate') # x轴标签
plt.ylabel('True Positive Rate') # y轴标签
plt.title('Receiver operating characteristic (ROC)') # 图片标题
plt.legend(loc="lower right") # 图例
plt.show()

# plot PR curve
from sklearn.metrics import precision_recall_curve
precision_5S, recall_5S, thresholds_5S = precision_recall_curve(y_test_5S, y_test_prod_5S)
precision_15S, recall_15S, thresholds_15S = precision_recall_curve(y_test_15S, y_test_prod_15S)
precision_25S, recall_25S, thresholds_25S = precision_recall_curve(y_test_25S, y_test_prod_25S)

plt.figure(figsize=(10,10))
plt.plot(recall_5S, precision_5S, color='darkorange', lw=2, label='5S PR curve (AUC = %0.2f)' % auc(recall_5S, precision_5S)) # lw: line width
plt.plot(recall_15S, precision_15S, color='green', lw=2, label='15S PR curve (AUC = %0.2f)' % auc(recall_15S, precision_15S)) # lw: line width
plt.plot(recall_25S, precision_25S, color='red', lw=2, label='25S PR curve (AUC = %0.2f)' % auc(recall_25S, precision_25S)) # lw: line width
# plt.xlim([0.0, 1.0]) # x轴范围
plt.ylim([0.0, 1.05]) # y轴范围
plt.xlabel('Recall') # x轴标签
plt.ylabel('Precision') # y轴标签
plt.title('Precision-Recall curve') # 图片标题
plt.legend(loc="lower right") # 图例
plt.show()




# Before_Pump_1D
# Reconstruction error threshold_5S:  0.2132132132132132
# Reconstruction error threshold_15S:  0.1871871871871872
# Reconstruction error threshold_25S:  0.26626626626626626
# 5S: F1 Score: 0.8722466960352423, Recall: 0.9369085173501577, Precision: 0.8159340659340659
# 15S: F1 Score: 0.9170579029733958, Recall: 0.9242902208201893, Precision: 0.9099378881987578
# 25S: F1 Score: 0.9540412044374009, Recall: 0.9495268138801262, Precision: 0.9585987261146497

# Before_Pump_3D
# Reconstruction error threshold_5S:  0.32932932932932935
# Reconstruction error threshold_15S:  0.21021021021021022
# Reconstruction error threshold_25S:  0.26926926926926925
# 5S: F1 Score: 0.8652931854199684, Recall: 0.861198738170347, Precision: 0.8694267515923567
# 15S: F1 Score: 0.8744186046511628, Recall: 0.889589905362776, Precision: 0.8597560975609756
# 25S: F1 Score: 0.9198717948717948, Recall: 0.9053627760252366, Precision: 0.9348534201954397






# Before_Pump_7D
# Reconstruction error threshold_5S:  0.4044044044044044
# Reconstruction error threshold_15S:  0.47047047047047047
# Reconstruction error threshold_25S:  0.38038038038038036
# 5S: F1 Score: 0.8310502283105022, Recall: 0.861198738170347, Precision: 0.8029411764705883
# 15S: F1 Score: 0.8607198748043818, Recall: 0.8675078864353313, Precision: 0.8540372670807453
# 25S: F1 Score: 0.8928571428571429, Recall: 0.8675078864353313, Precision: 0.919732441471572


# Before_After_Pump_7D
# Reconstruction error threshold_5S:  0.4754754754754755
# Reconstruction error threshold_15S:  0.3843843843843844
# Reconstruction error threshold_25S:  0.38238238238238237
# 5S: F1 Score: 0.718196457326892, Recall: 0.7034700315457413, Precision: 0.7335526315789473
# 15S: F1 Score: 0.8469055374592834, Recall: 0.8201892744479495, Precision: 0.8754208754208754
# 25S: F1 Score: 0.8906497622820919, Recall: 0.886435331230284, Precision: 0.8949044585987261
# Out:
# Reconstruction error threshold_5S:  0.32932932932932935
# Reconstruction error threshold_15S:  0.21021021021021022
# Reconstruction error threshold_25S:  0.26926926926926925
# 5S: F1 Score: 0.8652931854199684, Recall: 0.861198738170347, Precision: 0.8694267515923567
# 15S: F1 Score: 0.8744186046511628, Recall: 0.889589905362776, Precision: 0.8597560975609756
# 25S: F1 Score: 0.9198717948717948, Recall: 0.9053627760252366, Precision: 0.9348534201954397

# %%
# threshold = threshold_5S
# set_threshold(y_test_5S, test_mae_5S, threshold_5S)

# %%
# # 设置阈值
# threshold_1 = np.mean(test_mae_loss) + 3 * np.std(test_mae_loss)
# threshold_2 = np.mean(test_mae_loss) - 3 * np.std(test_mae_loss)
# print("Reconstruction error threshold: ", threshold_1, threshold_2)
# y_test_pred = np.where((test_mae_loss >= threshold_1) | (test_mae_loss< threshold_2) , 1, 0)

# # precision, recall, f1-score
# print('Recall: {}'.format(recall_score(y_test, y_test_pred)))
# print('Precision: {}'.format(precision_score(y_test, y_test_pred)))
# print('F1 score: {}'.format(f1_score(y_test, y_test_pred)))

# # plot confusion matrix
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_test_pred)
# plt.figure(figsize=(10, 6))
# sns.heatmap(cm, annot=True, fmt='d')
# plt.title('LSTM-AutoEncoder - Confusion Matrix')
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.show()
