# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import Input, Dense, LSTM, RepeatVector, TimeDistributed, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers
import tensorflow as tf

# %%
def del_no_pump_index(df):
    """
    Deletes the rows where the pump is not running
    """
    orginal = df.shape[0]

    # 找出没有被pump的pump_index
    pump_index = df['pump_index'].unique()
    nopump_index = []
    nopump_symbol = []
    for i in pump_index:
        df_pump = df[df['pump_index'] == i]
        # 如果df_pump的列gt不存在等于1, 打印i
        if 1 not in df_pump['gt'].values:
            nopump_symbol.append(df_pump['symbol'].unique().tolist()[0])
            nopump_index.append(i)
    print('nopump_index: ', nopump_index)
    print('nopump_symbol: ', nopump_symbol)

    print('df.shape: ', df.shape)
    print(df['pump_index'].unique().shape)

    # 删除pump_index的值等于48的行
    for i in nopump_index:
        df = df.drop(df[df['pump_index'] == i].index)

    print('df_cleaned.shape: ', df.shape)
    print(df['pump_index'].unique().shape)
    now = df.shape[0]
    print('deleted: ', orginal - now)
    return df

# %%
# --------------------------------------------------------------------------------------------------
def lstm_autoencoder(time_freq):
    df = pd.read_csv('before_pump/before_pump_5D_' + time_freq + '.csv', parse_dates=['date'])

    features = ['std_rush_order',
                'avg_rush_order',
                'std_trades',
                'std_volume',
                'avg_volume',
                'std_price',
                'avg_price',
                'avg_price_max',
                'hour_sin',
                'hour_cos',
                'minute_sin',
                'minute_cos']

    df = del_no_pump_index(df)

    X = df[features]
    Y = df['gt'].astype(int).values.ravel()

    # normalize
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    # normal data
    X_normal = X[Y == 0]
    Y_normal = Y[Y == 0]

    # abnormal data
    X_abnormal = X[Y == 1]
    Y_abnormal = Y[Y == 1]

    # train test split
    X_train, X_test, y_train, y_test = train_test_split(X_normal, Y_normal, test_size=0.2, random_state=2023)
    
    # 拼接X_test和X_abnormal
    X_test = np.concatenate((X_test, X_abnormal), axis=0)
    y_test = np.concatenate((y_test, Y_abnormal), axis=0)

    # 将时间序列数据转换为适用于LSTM自编码器的输入格式
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    # 构建LSTM自编码器模型
    reg = 0.0001
    inputs = Input(shape=(X_train.shape[1],X_train.shape[2]))
    encoded = LSTM(32, activation='relu', return_sequences=True, kernel_regularizer=regularizers.l2(reg))(inputs)
    encoded = LSTM(16, activation='relu', return_sequences=False)(encoded)
    decoded = RepeatVector(X_train.shape[1])(encoded)
    decoded = LSTM(16, activation='relu', return_sequences=True,)(decoded)
    decoded = LSTM(32, activation='relu', return_sequences=True)(decoded)
    outputs = TimeDistributed(Dense(X_train.shape[2]))(decoded)
    autoencoder = Model(inputs, outputs)
    autoencoder.compile(optimizer='adam', loss='mae')
    # adam = optimizers.Adam(learning_rate=0.0001)
    # autoencoder.compile(optimizer=adam, loss='mae')
    # autoencoder.summary()
    
    # 使用训练数据训练LSTM自编码器模型
    early_stopping = EarlyStopping(monitor='val_loss'
                                # , min_delta=0.0001
                                , patience=12
                                , verbose=1
                                # , mode='min'
                                , restore_best_weights=True)
    history= autoencoder.fit(X_train, X_train
                            , epochs=150
                            , batch_size=32
                            , validation_split=0.1
                            , callbacks=[early_stopping]
                            )

    # plot loss curve
    fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
    ax.plot(history.history['loss'], 'b', label='Train', linewidth=2)
    ax.plot(history.history['val_loss'], 'r', label='Validation', linewidth=2)
    ax.set_title('LSTM-AutoEncoder Model loss', fontsize=16)
    ax.set_ylabel('Loss (mae)')
    ax.set_xlabel('Epoch')
    ax.legend(loc='upper right')
    plt.show()

    # 使用训练好的LSTM自编码器重构测试数据
    X_test_pred = autoencoder.predict(X_test)
    X_test_pred = X_test_pred.reshape(X_test_pred.shape[0], X_test_pred.shape[2])
    testX = X_test.reshape(X_test.shape[0], X_test.shape[2])

    # 计算还原误差MAE
    test_mae = np.mean(np.abs(testX - X_test_pred), axis=1)

    return autoencoder, test_mae, y_test



# --------------------------------------------------------------------------------------------------
def pick_threshold(y, preds):
    thresholds = np.linspace(0, 1, 1000)
    f1_scores = [f1_score(y, preds > t) for t in thresholds]
    precision_scores = [precision_score(y, preds > t) for t in thresholds]
    recall_scores = [recall_score(y, preds > t) for t in thresholds]
    plt.figure(figsize=(12, 6))
    plt.plot(thresholds, f1_scores, label='F1 Score')
    plt.plot(thresholds, precision_scores, label='Precision')
    plt.plot(thresholds, recall_scores, label='Recall')
    plt.axvline(x=thresholds[np.argmax(f1_scores)], color='r', linestyle='--', label='Max F1 Score')
    plt.title('F1 Score w.r.t varying threshold')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.show()
    best_threshold = thresholds[np.argmax(f1_scores)]
    print('Best threshold: ', best_threshold)
    print('Best F1 Score: ', np.max(f1_scores))
    print('Recall: ', recall_score(y, preds > best_threshold))
    print('Precision: ', precision_score(y, preds > best_threshold))
    

    cm = confusion_matrix(y, preds > best_threshold)
    plt.figure(figsize=(10, 6))
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title('LSTM-AutoEncoder - Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
    return best_threshold
# ------------------------------set threshold--------------------------------------------------------
def set_threshold(y_test, test_mae, threshold):
    # 设置阈值
    threshold = threshold
    print("Reconstruction error threshold: ", threshold)
    y_test_pred = np.where(test_mae >= threshold , 1, 0)

    # precision, recall, f1-score
    print('F1 score: {}'.format(f1_score(y_test, y_test_pred)))
    print('Recall: {}'.format(recall_score(y_test, y_test_pred)))
    print('Precision: {}'.format(precision_score(y_test, y_test_pred)))
    

    # plot confusion matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_test_pred)
    plt.figure(figsize=(10, 6))
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title('LSTM-AutoEncoder - Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %% [markdown]
# # LSTM AutoEncoder

# %% [markdown]
# - 25S

# %%
autoencoder_25S, test_mae_25S, y_test_25S = lstm_autoencoder(time_freq='25S') # 6m 51s
# Out:
# nopump_index:  []
# nopump_symbol:  []
# df.shape:  (134699, 16)
# (317,)
# df_cleaned.shape:  (134699, 16)
# (317,)
# deleted:  0
# Epoch 1/150
# 3024/3024 [==============================] - 12s 3ms/step - loss: 0.1651 - val_loss: 0.0949
# Epoch 2/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0903 - val_loss: 0.0629
# Epoch 3/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0466 - val_loss: 0.0466
# Epoch 4/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0438 - val_loss: 0.0453
# Epoch 5/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0432 - val_loss: 0.0418
# Epoch 6/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0424 - val_loss: 0.0415
# Epoch 7/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0341 - val_loss: 0.0320
# Epoch 8/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0299 - val_loss: 0.0301
# Epoch 9/150
# 3024/3024 [==============================] - 8s 2ms/step - loss: 0.0292 - val_loss: 0.0296
# Epoch 10/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0287 - val_loss: 0.0288
# Epoch 11/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0283 - val_loss: 0.0287
# Epoch 12/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0276 - val_loss: 0.0296
# Epoch 13/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0255 - val_loss: 0.0217
# Epoch 14/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0172 - val_loss: 0.0178
# Epoch 15/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0159 - val_loss: 0.0156
# Epoch 16/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0155 - val_loss: 0.0150
# Epoch 17/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0154 - val_loss: 0.0180
# Epoch 18/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0151 - val_loss: 0.0161
# Epoch 19/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0149 - val_loss: 0.0149
# Epoch 20/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0148 - val_loss: 0.0153
# Epoch 21/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0147 - val_loss: 0.0148
# Epoch 22/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0145 - val_loss: 0.0179
# Epoch 23/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0145 - val_loss: 0.0164
# Epoch 24/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0144 - val_loss: 0.0149
# Epoch 25/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0142 - val_loss: 0.0143
# Epoch 26/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0142 - val_loss: 0.0144
# Epoch 27/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0141 - val_loss: 0.0139
# Epoch 28/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0140 - val_loss: 0.0143
# Epoch 29/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0140 - val_loss: 0.0144
# Epoch 30/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0139 - val_loss: 0.0141
# Epoch 31/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0139 - val_loss: 0.0149
# Epoch 32/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0139 - val_loss: 0.0137
# Epoch 33/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0138 - val_loss: 0.0133
# Epoch 34/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0139 - val_loss: 0.0151
# Epoch 35/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 36/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0137 - val_loss: 0.0132
# Epoch 37/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0137 - val_loss: 0.0151
# Epoch 38/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0137 - val_loss: 0.0157
# Epoch 39/150
# 3024/3024 [==============================] - 6s 2ms/step - loss: 0.0136 - val_loss: 0.0142
# Epoch 40/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0136 - val_loss: 0.0131
# Epoch 41/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0135 - val_loss: 0.0154
# Epoch 42/150
# 3024/3024 [==============================] - 8s 2ms/step - loss: 0.0135 - val_loss: 0.0151
# Epoch 43/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0135 - val_loss: 0.0126
# Epoch 44/150
# 3024/3024 [==============================] - 9s 3ms/step - loss: 0.0135 - val_loss: 0.0131
# Epoch 45/150
# 3024/3024 [==============================] - 9s 3ms/step - loss: 0.0134 - val_loss: 0.0137
# Epoch 46/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0134 - val_loss: 0.0134
# Epoch 47/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0133 - val_loss: 0.0128
# Epoch 48/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 49/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0134 - val_loss: 0.0131
# Epoch 50/150
# 3024/3024 [==============================] - 9s 3ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 51/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0133 - val_loss: 0.0131
# Epoch 52/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0133 - val_loss: 0.0145
# Epoch 53/150
# 3024/3024 [==============================] - 7s 2ms/step - loss: 0.0133 - val_loss: 0.0137
# Epoch 54/150
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0133 - val_loss: 0.0138
# Epoch 55/150
# 3012/3024 [============================>.] - ETA: 0s - loss: 0.0133Restoring model weights from the end of the best epoch: 43.
# 3024/3024 [==============================] - 8s 3ms/step - loss: 0.0133 - val_loss: 0.0130
# Epoch 55: early stopping
# 850/850 [==============================] - 1s 1ms/step

# %%
threshold_25S = pick_threshold(y_test_25S, test_mae_25S)



# Before 1 Days
# Best threshold:  0.26626626626626626
# Best F1 Score:  0.9540412044374009
# Recall:  0.9495268138801262
# Precision:  0.9585987261146497

# Before 3 Days
# Best threshold:  0.26926926926926925
# Best F1 Score:  0.9198717948717948
# Recall:  0.9053627760252366
# Precision:  0.9348534201954397

# Before 5 Days
# Best threshold:  0.30430430430430433
# Best F1 Score:  0.9245585874799358
# Recall:  0.9085173501577287
# Precision:  0.9411764705882353

# Before 7 Days
# Best threshold:  0.38038038038038036
# Best F1 Score:  0.8928571428571429
# Recall:  0.8675078864353313
# Precision:  0.919732441471572
# Out:
# Best threshold:  0.30430430430430433
# Best F1 Score:  0.9245585874799358
# Recall:  0.9085173501577287
# Precision:  0.9411764705882353

# %% [markdown]
# - 15S

# %%
autoencoder_15S, test_mae_15S, y_test_15S = lstm_autoencoder(time_freq='15S') # 4m 32s
# Out:
# nopump_index:  []
# nopump_symbol:  []
# df.shape:  (158771, 16)
# (317,)
# df_cleaned.shape:  (158771, 16)
# (317,)
# deleted:  0
# Epoch 1/150
# 3566/3566 [==============================] - 13s 3ms/step - loss: 0.1697 - val_loss: 0.0718
# Epoch 2/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0631 - val_loss: 0.0633
# Epoch 3/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0492 - val_loss: 0.0442
# Epoch 4/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0371 - val_loss: 0.0359
# Epoch 5/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0259 - val_loss: 0.0230
# Epoch 6/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0225 - val_loss: 0.0253
# Epoch 7/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0216 - val_loss: 0.0221
# Epoch 8/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0213 - val_loss: 0.0214
# Epoch 9/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0209 - val_loss: 0.0218
# Epoch 10/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0207 - val_loss: 0.0250
# Epoch 11/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0205 - val_loss: 0.0233
# Epoch 12/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0203 - val_loss: 0.0210
# Epoch 13/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0201 - val_loss: 0.0201
# Epoch 14/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0200 - val_loss: 0.0217
# Epoch 15/150
# 3566/3566 [==============================] - 9s 3ms/step - loss: 0.0198 - val_loss: 0.0207
# Epoch 16/150
# 3566/3566 [==============================] - 9s 2ms/step - loss: 0.0197 - val_loss: 0.0227
# Epoch 17/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0196 - val_loss: 0.0197
# Epoch 18/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0195 - val_loss: 0.0196
# Epoch 19/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0194 - val_loss: 0.0233
# Epoch 20/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0193 - val_loss: 0.0208
# Epoch 21/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0192 - val_loss: 0.0194
# Epoch 22/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0191 - val_loss: 0.0212
# Epoch 23/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0190 - val_loss: 0.0214
# Epoch 24/150
# 3566/3566 [==============================] - 10s 3ms/step - loss: 0.0189 - val_loss: 0.0214
# Epoch 25/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0188 - val_loss: 0.0202
# Epoch 26/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 27/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0183 - val_loss: 0.0191
# Epoch 28/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0172 - val_loss: 0.0205
# Epoch 29/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0153 - val_loss: 0.0159
# Epoch 30/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0149 - val_loss: 0.0158
# Epoch 31/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0146 - val_loss: 0.0139
# Epoch 32/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0145 - val_loss: 0.0142
# Epoch 33/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0145 - val_loss: 0.0152
# Epoch 34/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0144 - val_loss: 0.0168
# Epoch 35/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0143 - val_loss: 0.0150
# Epoch 36/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0143 - val_loss: 0.0147
# Epoch 37/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0141 - val_loss: 0.0147
# Epoch 38/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0141 - val_loss: 0.0136
# Epoch 39/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0141 - val_loss: 0.0139
# Epoch 40/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0141 - val_loss: 0.0148
# Epoch 41/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0140 - val_loss: 0.0146
# Epoch 42/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0139 - val_loss: 0.0134
# Epoch 43/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 44/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0139 - val_loss: 0.0145
# Epoch 45/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0138 - val_loss: 0.0147
# Epoch 46/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0137 - val_loss: 0.0158
# Epoch 47/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0138 - val_loss: 0.0162
# Epoch 48/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0136 - val_loss: 0.0148
# Epoch 49/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 50/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0137 - val_loss: 0.0151
# Epoch 51/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0136 - val_loss: 0.0158
# Epoch 52/150
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0135 - val_loss: 0.0150
# Epoch 53/150
# 3566/3566 [==============================] - 7s 2ms/step - loss: 0.0136 - val_loss: 0.0136
# Epoch 54/150
# 3554/3566 [============================>.] - ETA: 0s - loss: 0.0135Restoring model weights from the end of the best epoch: 42.
# 3566/3566 [==============================] - 8s 2ms/step - loss: 0.0135 - val_loss: 0.0136
# Epoch 54: early stopping
# 1001/1001 [==============================] - 1s 934us/step

# %%
threshold_15S = pick_threshold(y_test_15S, test_mae_15S)



# Before 1 Days
# Best threshold:  0.1871871871871872
# Best F1 Score:  0.9170579029733958
# Recall:  0.9242902208201893
# Precision:  0.9099378881987578

# Before 3 Days
# Best threshold:  0.21021021021021022
# Best F1 Score:  0.8744186046511628
# Recall:  0.889589905362776
# Precision:  0.8597560975609756

# Before 7 Days
# Best threshold:  0.47047047047047047
# Best F1 Score:  0.8607198748043818
# Recall:  0.8675078864353313
# Precision:  0.8540372670807453
# Out:
# Best threshold:  0.35535535535535534
# Best F1 Score:  0.8944881889763779
# Recall:  0.8958990536277602
# Precision:  0.8930817610062893

# %% [markdown]
# - 5S

# %%
autoencoder_5S, test_mae_5S, y_test_5S = lstm_autoencoder(time_freq='5S')
# Out:
# nopump_index:  []
# nopump_symbol:  []
# df.shape:  (214312, 16)
# (317,)
# df_cleaned.shape:  (214312, 16)
# (317,)
# deleted:  0
# Epoch 1/150
# 4815/4815 [==============================] - 14s 2ms/step - loss: 0.1597 - val_loss: 0.0808
# Epoch 2/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0796 - val_loss: 0.0789
# Epoch 3/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0783 - val_loss: 0.0779
# Epoch 4/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0654 - val_loss: 0.0591
# Epoch 5/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0570 - val_loss: 0.0564
# Epoch 6/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0507 - val_loss: 0.0241
# Epoch 7/150
# 4815/4815 [==============================] - 12s 3ms/step - loss: 0.0241 - val_loss: 0.0225
# Epoch 8/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0233 - val_loss: 0.0240
# Epoch 9/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0230 - val_loss: 0.0229
# Epoch 10/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0227 - val_loss: 0.0225
# Epoch 11/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0226 - val_loss: 0.0227
# Epoch 12/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 13/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0222 - val_loss: 0.0217
# Epoch 14/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0221 - val_loss: 0.0208
# Epoch 15/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0220 - val_loss: 0.0216
# Epoch 16/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0220 - val_loss: 0.0204
# Epoch 17/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0219 - val_loss: 0.0213
# Epoch 18/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 19/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0216 - val_loss: 0.0210
# Epoch 20/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0217 - val_loss: 0.0216
# Epoch 21/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 22/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0214 - val_loss: 0.0206
# Epoch 23/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0212 - val_loss: 0.0205
# Epoch 24/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0204 - val_loss: 0.0189
# Epoch 25/150
# 4815/4815 [==============================] - 9s 2ms/step - loss: 0.0167 - val_loss: 0.0160
# Epoch 26/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0155 - val_loss: 0.0147
# Epoch 27/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0152 - val_loss: 0.0142
# Epoch 28/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0151 - val_loss: 0.0157
# Epoch 29/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0149 - val_loss: 0.0149
# Epoch 30/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0149 - val_loss: 0.0141
# Epoch 31/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0147 - val_loss: 0.0155
# Epoch 32/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0146 - val_loss: 0.0147
# Epoch 33/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0147 - val_loss: 0.0148
# Epoch 34/150
# 4815/4815 [==============================] - 9s 2ms/step - loss: 0.0146 - val_loss: 0.0151
# Epoch 35/150
# 4815/4815 [==============================] - 10s 2ms/step - loss: 0.0147 - val_loss: 0.0143
# Epoch 36/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0146 - val_loss: 0.0149
# Epoch 37/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0145 - val_loss: 0.0144
# Epoch 38/150
# 4815/4815 [==============================] - 11s 2ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 39/150
# 4815/4815 [==============================] - 13s 3ms/step - loss: 0.0144 - val_loss: 0.0140
# Epoch 40/150
# 4815/4815 [==============================] - 13s 3ms/step - loss: 0.0144 - val_loss: 0.0142
# Epoch 41/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0144 - val_loss: 0.0153
# Epoch 42/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0143 - val_loss: 0.0143
# Epoch 43/150
# 4815/4815 [==============================] - 16s 3ms/step - loss: 0.0142 - val_loss: 0.0146
# Epoch 44/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0142 - val_loss: 0.0131
# Epoch 45/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0143 - val_loss: 0.0138
# Epoch 46/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0142 - val_loss: 0.0138
# Epoch 47/150
# 4815/4815 [==============================] - 16s 3ms/step - loss: 0.0141 - val_loss: 0.0140
# Epoch 48/150
# 4815/4815 [==============================] - 16s 3ms/step - loss: 0.0141 - val_loss: 0.0137
# Epoch 49/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0141 - val_loss: 0.0147
# Epoch 50/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0141 - val_loss: 0.0140
# Epoch 51/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0140 - val_loss: 0.0150
# Epoch 52/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0140 - val_loss: 0.0140
# Epoch 53/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 54/150
# 4815/4815 [==============================] - 16s 3ms/step - loss: 0.0140 - val_loss: 0.0147
# Epoch 55/150
# 4815/4815 [==============================] - 16s 3ms/step - loss: 0.0139 - val_loss: 0.0149
# Epoch 56/150
# 4815/4815 [==============================] - 16s 3ms/step - loss: 0.0139 - val_loss: 0.0134
# Epoch 57/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0139 - val_loss: 0.0152
# Epoch 58/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0138 - val_loss: 0.0138
# Epoch 59/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0139 - val_loss: 0.0134
# Epoch 60/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0138 - val_loss: 0.0129
# Epoch 61/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0137 - val_loss: 0.0135
# Epoch 62/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0138 - val_loss: 0.0130
# Epoch 63/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0137 - val_loss: 0.0152
# Epoch 64/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0136 - val_loss: 0.0124
# Epoch 65/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0136 - val_loss: 0.0140
# Epoch 66/150
# 4815/4815 [==============================] - 14s 3ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 67/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0137 - val_loss: 0.0152
# Epoch 68/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0136 - val_loss: 0.0127
# Epoch 69/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0135 - val_loss: 0.0141
# Epoch 70/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0135 - val_loss: 0.0138
# Epoch 71/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0135 - val_loss: 0.0137
# Epoch 72/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0135 - val_loss: 0.0148
# Epoch 73/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0135 - val_loss: 0.0131
# Epoch 74/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 75/150
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0134 - val_loss: 0.0132
# Epoch 76/150
# 4799/4815 [============================>.] - ETA: 0s - loss: 0.0134Restoring model weights from the end of the best epoch: 64.
# 4815/4815 [==============================] - 15s 3ms/step - loss: 0.0134 - val_loss: 0.0138
# Epoch 76: early stopping
# 1348/1348 [==============================] - 2s 1ms/step

# %%
threshold_5S = pick_threshold(y_test_5S, test_mae_5S)



# Before 1 Day
# Best threshold:  0.2132132132132132
# Best F1 Score:  0.8722466960352423
# Recall:  0.9369085173501577
# Precision:  0.8159340659340659

# Before 3 Day
# Best threshold:  0.32932932932932935
# Best F1 Score:  0.8652931854199684
# Recall:  0.861198738170347
# Precision:  0.8694267515923567


# Before 7 Day
# Best threshold:  0.4044044044044044
# Best F1 Score:  0.8310502283105022
# Recall:  0.861198738170347
# Precision:  0.8029411764705883
# Out:
# Best threshold:  0.3943943943943944
# Best F1 Score:  0.8452012383900928
# Recall:  0.861198738170347
# Precision:  0.8297872340425532

# %%
# 设置阈值
print("Reconstruction error threshold_5S: ", threshold_5S)
print("Reconstruction error threshold_15S: ", threshold_15S)
print("Reconstruction error threshold_25S: ", threshold_25S)

# Sigmoid 函数
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


y_test_pred_5S = np.where(test_mae_5S >= threshold_5S , 1, 0)
y_test_pred_15S = np.where(test_mae_15S >= threshold_15S , 1, 0)
y_test_pred_25S = np.where(test_mae_25S >= threshold_25S , 1, 0)

y_test_prod_5S = sigmoid(y_test_pred_5S)
y_test_prod_15S = sigmoid(y_test_pred_15S)
y_test_prod_25S = sigmoid(y_test_pred_25S)

# precision, recall, f1-score
from sklearn.metrics import f1_score, recall_score, precision_score
F1_score_5S = f1_score(y_test_5S, y_test_pred_5S)
Recall_5S = recall_score(y_test_5S, y_test_pred_5S)
Precision_5S = precision_score(y_test_5S, y_test_pred_5S)

F1_score_15S = f1_score(y_test_15S, y_test_pred_15S)
Recall_15S = recall_score(y_test_15S, y_test_pred_15S)
Precision_15S = precision_score(y_test_15S, y_test_pred_15S)

F1_score_25S = f1_score(y_test_25S, y_test_pred_25S)
Recall_25S = recall_score(y_test_25S, y_test_pred_25S)
Precision_25S = precision_score(y_test_25S, y_test_pred_25S)

print('5S: F1 Score: {}, Recall: {}, Precision: {}'.format(F1_score_5S, Recall_5S, Precision_5S))
print('15S: F1 Score: {}, Recall: {}, Precision: {}'.format(F1_score_15S, Recall_15S, Precision_15S))
print('25S: F1 Score: {}, Recall: {}, Precision: {}'.format(F1_score_25S, Recall_25S, Precision_25S))

# plot confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix_5S = confusion_matrix(y_test_5S, y_test_pred_5S)
confusion_matrix_15S = confusion_matrix(y_test_15S, y_test_pred_15S)
confusion_matrix_25S = confusion_matrix(y_test_25S, y_test_pred_25S)

plt.figure(figsize=(40,10))
plt.subplot(1,3,1)
plt.title('5S')
sns.heatmap(confusion_matrix_5S, annot=True, fmt="d", cmap=plt.cm.Blues, xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted label')
plt.ylabel('True label')

plt.subplot(1,3,2)
plt.title('15S')
sns.heatmap(confusion_matrix_15S, annot=True, fmt="d", cmap=plt.cm.Blues, xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted label')
plt.ylabel('True label')

plt.subplot(1,3,3)
plt.title('25S')
sns.heatmap(confusion_matrix_25S, annot=True, fmt="d", cmap=plt.cm.Blues, xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted label')
plt.ylabel('True label')


# plot ROC curve
from sklearn.metrics import roc_curve, auc
# fpr_5S, tpr_5S, thresholds_5S = roc_curve(y_test_5S, y_test_pred_5S)
fpr_5S, tpr_5S, thresholds_5S = roc_curve(y_test_5S, y_test_prod_5S)

roc_auc_5S = auc(fpr_5S, tpr_5S)

# fpr_15S, tpr_15S, thresholds_15S = roc_curve(y_test_15S, y_test_pred_15S)
fpr_15S, tpr_15S, thresholds_15S = roc_curve(y_test_15S, y_test_prod_15S)
roc_auc_15S = auc(fpr_15S, tpr_15S)

# fpr_25S, tpr_25S, thresholds_25S = roc_curve(y_test_25S, y_test_pred_25S)
fpr_25S, tpr_25S, thresholds_25S = roc_curve(y_test_25S, y_test_prod_25S)
roc_auc_25S = auc(fpr_25S, tpr_25S)

plt.figure(figsize=(10,10))
plt.plot(fpr_5S, tpr_5S, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc_5S) # lw: line width
plt.plot(fpr_15S, tpr_15S, color='green', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc_15S) # lw: line width
plt.plot(fpr_25S, tpr_25S, color='red', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc_25S) # lw: line width
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--') # 画对角线
# plt.xlim([0.0, 1.0]) # x轴范围
plt.ylim([0.0, 1.05]) # y轴范围
plt.xlabel('False Positive Rate') # x轴标签
plt.ylabel('True Positive Rate') # y轴标签
plt.title('Receiver operating characteristic (ROC)') # 图片标题
plt.legend(loc="lower right") # 图例
plt.show()

# plot PR curve
from sklearn.metrics import precision_recall_curve
precision_5S, recall_5S, thresholds_5S = precision_recall_curve(y_test_5S, y_test_prod_5S)
precision_15S, recall_15S, thresholds_15S = precision_recall_curve(y_test_15S, y_test_prod_15S)
precision_25S, recall_25S, thresholds_25S = precision_recall_curve(y_test_25S, y_test_prod_25S)

plt.figure(figsize=(10,10))
plt.plot(recall_5S, precision_5S, color='darkorange', lw=2, label='5S PR curve (AUC = %0.2f)' % auc(recall_5S, precision_5S)) # lw: line width
plt.plot(recall_15S, precision_15S, color='green', lw=2, label='15S PR curve (AUC = %0.2f)' % auc(recall_15S, precision_15S)) # lw: line width
plt.plot(recall_25S, precision_25S, color='red', lw=2, label='25S PR curve (AUC = %0.2f)' % auc(recall_25S, precision_25S)) # lw: line width
# plt.xlim([0.0, 1.0]) # x轴范围
plt.ylim([0.0, 1.05]) # y轴范围
plt.xlabel('Recall') # x轴标签
plt.ylabel('Precision') # y轴标签
plt.title('Precision-Recall curve') # 图片标题
plt.legend(loc="lower right") # 图例
plt.show()




# Before_Pump_1D
# Reconstruction error threshold_5S:  0.2132132132132132
# Reconstruction error threshold_15S:  0.1871871871871872
# Reconstruction error threshold_25S:  0.26626626626626626
# 5S: F1 Score: 0.8722466960352423, Recall: 0.9369085173501577, Precision: 0.8159340659340659
# 15S: F1 Score: 0.9170579029733958, Recall: 0.9242902208201893, Precision: 0.9099378881987578
# 25S: F1 Score: 0.9540412044374009, Recall: 0.9495268138801262, Precision: 0.9585987261146497

# Before_Pump_3D
# Reconstruction error threshold_5S:  0.32932932932932935
# Reconstruction error threshold_15S:  0.21021021021021022
# Reconstruction error threshold_25S:  0.26926926926926925
# 5S: F1 Score: 0.8652931854199684, Recall: 0.861198738170347, Precision: 0.8694267515923567
# 15S: F1 Score: 0.8744186046511628, Recall: 0.889589905362776, Precision: 0.8597560975609756
# 25S: F1 Score: 0.9198717948717948, Recall: 0.9053627760252366, Precision: 0.9348534201954397

# Before_Pump_5D
# Reconstruction error threshold_5S:  0.3943943943943944
# Reconstruction error threshold_15S:  0.35535535535535534
# Reconstruction error threshold_25S:  0.30430430430430433
# 5S: F1 Score: 0.8452012383900928, Recall: 0.861198738170347, Precision: 0.8297872340425532
# 15S: F1 Score: 0.8944881889763779, Recall: 0.8958990536277602, Precision: 0.8930817610062893
# 25S: F1 Score: 0.9245585874799358, Recall: 0.9085173501577287, Precision: 0.9411764705882353

# Before_Pump_7D
# Reconstruction error threshold_5S:  0.4044044044044044
# Reconstruction error threshold_15S:  0.47047047047047047
# Reconstruction error threshold_25S:  0.38038038038038036
# 5S: F1 Score: 0.8310502283105022, Recall: 0.861198738170347, Precision: 0.8029411764705883
# 15S: F1 Score: 0.8607198748043818, Recall: 0.8675078864353313, Precision: 0.8540372670807453
# 25S: F1 Score: 0.8928571428571429, Recall: 0.8675078864353313, Precision: 0.919732441471572


# Before_After_Pump_7D
# Reconstruction error threshold_5S:  0.4754754754754755
# Reconstruction error threshold_15S:  0.3843843843843844
# Reconstruction error threshold_25S:  0.38238238238238237
# 5S: F1 Score: 0.718196457326892, Recall: 0.7034700315457413, Precision: 0.7335526315789473
# 15S: F1 Score: 0.8469055374592834, Recall: 0.8201892744479495, Precision: 0.8754208754208754
# 25S: F1 Score: 0.8906497622820919, Recall: 0.886435331230284, Precision: 0.8949044585987261
# Out:
# Reconstruction error threshold_5S:  0.3943943943943944
# Reconstruction error threshold_15S:  0.35535535535535534
# Reconstruction error threshold_25S:  0.30430430430430433
# 5S: F1 Score: 0.8452012383900928, Recall: 0.861198738170347, Precision: 0.8297872340425532
# 15S: F1 Score: 0.8944881889763779, Recall: 0.8958990536277602, Precision: 0.8930817610062893
# 25S: F1 Score: 0.9245585874799358, Recall: 0.9085173501577287, Precision: 0.9411764705882353

# %%
# threshold = threshold_5S
# set_threshold(y_test_5S, test_mae_5S, threshold_5S)

# %%
# # 设置阈值
# threshold_1 = np.mean(test_mae_loss) + 3 * np.std(test_mae_loss)
# threshold_2 = np.mean(test_mae_loss) - 3 * np.std(test_mae_loss)
# print("Reconstruction error threshold: ", threshold_1, threshold_2)
# y_test_pred = np.where((test_mae_loss >= threshold_1) | (test_mae_loss< threshold_2) , 1, 0)

# # precision, recall, f1-score
# print('Recall: {}'.format(recall_score(y_test, y_test_pred)))
# print('Precision: {}'.format(precision_score(y_test, y_test_pred)))
# print('F1 score: {}'.format(f1_score(y_test, y_test_pred)))

# # plot confusion matrix
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_test_pred)
# plt.figure(figsize=(10, 6))
# sns.heatmap(cm, annot=True, fmt='d')
# plt.title('LSTM-AutoEncoder - Confusion Matrix')
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.show()
